# %%
import numpy as np
import random
from PIL import Image

# %%
a = np.random.randint(255, size=(384, 512, 3)).astype('uint8')

# %%
b = Image.fromarray(a)
b
# Out:
# <PIL.Image.Image image mode=RGB size=512x384 at 0x116413590>

# %%
b.save("prueba.jpg")
